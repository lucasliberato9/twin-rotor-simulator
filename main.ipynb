# %% [markdown]
# ### Imports

# %%
import cvxpy as cp
import numpy as np

# %% [markdown]
# ### Parâmetros a serem dados ou medidos
# (Os valores utilizados abaixo são referentes aos utilizados no artigo. Devem ser substituídos.)

# %%
# Gyroscopic constant
k_g = 0.2

# Length of the tail part of the beam
l_t = 0.282

# Length of the main part of the beam
l_m = 0.246

# Length of the counterweight beam
l_b = 0.290

# Distance between the counterweight and the joint
l_cb = 0.276

# Radius of the tail shield
r_ts = 0.1

# Radius of the main shield
r_ms = 0.155

# Mass of the counterweight
m_cb = 0.068

# Mass of the counterweight beam
m_b = 0.022

# Mass of the main part of the beam
m_m = 0.014

# Mass of the main DC motor
m_mr = 0.236

# Mass of the main shield
m_ms = 0.219

# Armature inductance of the DC motors
L_a = L_ah = L_av = 0.86e-3

# Torque constant of the DC motors
k_a = k_ah = k_av = 0.0202

# Mass of the tail part of the beam
m_t = 0.015

# Mass of the tail DC motor
m_tr = 0.221

# Mass of the tail shield
m_ts = 0.119

# Armature resistance of the DC motors
R_a = R_ah = R_av = 8

# Input constance of the tail motor
k_1 = 6.5

# Input constance of the main motor
k_2 = 8.5
